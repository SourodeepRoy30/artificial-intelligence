# %% [markdown]
# ## Topics Covered
#
# - [Variables & Data Types](#variables--data-types)
# - [Type Conversion & Casting](#type-conversion--casting)
# - [Operators](#operators-arithmetic-comparison-logical-bitwise-assignment)
# - [Strings & String Methods](#strings--string-methods)
# - [Control Flow (if/elif/else)](#control-flow-ifelifelse)
# - [Loops (for, while, break, continue, else)](#loops-for-while-break-continue-else)
# - [Data Structures: Lists](#data-structures-lists)
# - [Data Structures: Tuples](#data-structures-tuples)
# - [Data Structures: Sets](#data-structures-sets)
# - [Data Structures: Dictionaries](#data-structures-dictionaries)
# - [List/Dict/Set Comprehensions](#listdictset-comprehensions)
# - [Functions (args, kwargs, default/keyword arguments)](#functions-args-kwargs-defaultkeyword-arguments)
# - [Lambda Functions](#lambda-functions)
# - [Scope (local, global, nonlocal, LEGB rule)](#scope-local-global-nonlocal-legb-rule)
# - [Higher-Order Functions (map, filter, reduce)](#higher-order-functions-map-filter-reduce)
# - [Decorators](#decorators)
# - [Generators & Iterators](#generators--iterators)
# - [Exception Handling](#exception-handling-tryexceptelsefinally-custom-exceptions)
# - [File I/O](#file-io)
# - [Modules & Packages](#modules--packages)
# - [OOP: Classes & Objects](#oop-classes--objects)
# - [OOP: Inheritance & Polymorphism](#oop-inheritance--polymorphism)
# - [OOP: Encapsulation & Abstraction](#oop-encapsulation--abstraction)
# - [OOP: Magic/Dunder Methods](#oop-magicdunder-methods)
# - [Context Managers (with statement)](#context-managers-with-statement)
# - [*args and **kwargs (deep dive)](#args-and-kwargs-deep-dive)

# %% [markdown]
# ## Variables & Data Types
